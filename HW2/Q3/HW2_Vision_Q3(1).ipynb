# %% [markdown]
# **Data preparation**

# %%
import zipfile
import os

zip_filename = "airplanes.zip"
extract_dir = "airplanes_data"
os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print(f"Files extracted to directory: {extract_dir}")
print(os.listdir(extract_dir))
# Out:
# Files extracted to directory: airplanes_data
# ['Airplanes_Annotations', 'Images']

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Define paths
annotation_path = "airplanes_data/Airplanes_Annotations/Airplanes_Annotations"
image_path = "airplanes_data/Images/Images"
output_path = "Processed_Dataset"

os.makedirs(output_path, exist_ok=True)

def load_annotations(annotation_dir, image_dir):
    """
    Load annotations and images, ensuring the first row of the CSV is the airplane count.
    """
    data = []

   
    print(f"Checking annotation directory: {annotation_dir}")
    print(f"Checking image directory: {image_dir}")

    annotation_files = os.listdir(annotation_dir)
    image_files = os.listdir(image_dir)

    print(f"Found {len(annotation_files)} annotation files and {len(image_files)} image files.")

    for csv_file in annotation_files:
        if csv_file.endswith(".csv"):
            annotation_file = os.path.join(annotation_dir, csv_file)
            image_file = os.path.join(image_dir, csv_file.replace(".csv", ".jpg"))

            if not os.path.exists(image_file):
                print(f"Image file missing for {csv_file}, expected: {image_file}")
                continue

            # Read the annotation file
            try:
                with open(annotation_file, "r") as f:
                    lines = f.readlines()

                    if not lines:
                        print(f"Empty file: {annotation_file}")
                        continue

                  
                    try:
                        airplane_count = int(lines[0].strip())  
                        print(f"Processing {csv_file}, airplanes: {airplane_count}")
                    except ValueError:
                        print(f"Invalid airplane count in file: {annotation_file}")
                        continue

                 
                    for idx, line in enumerate(lines[1:]):  
                        parts = line.strip().split()  

                     
                        print(f"Line {idx + 1} in {csv_file}: {line.strip()}")
                        print(f"Parsed parts: {parts}")

                        if len(parts) == 4:  
                            try:
                                x_min, y_min, x_max, y_max = map(int, parts)

                                data.append({
                                    "image": image_file,
                                    "bbox": [x_min, y_min, x_max, y_max],
                                    "label": "airplane"
                                })
                                print(f"Added bounding box: {x_min, y_min, x_max, y_max}")
                            except ValueError:
                                print(f"Invalid bounding box values in file: {annotation_file}, line: {line.strip()}")
                        else:
                            print(f"Skipping invalid line in file: {annotation_file}, line: {line.strip()}")
            except Exception as e:
                print(f"Error reading file {annotation_file}: {e}")

    print(f"Total valid annotations: {len(data)}")
    return data


dataset = load_annotations(annotation_path, image_path)


if not dataset:
    print("No data found. Please check the annotation and image directories.")
    exit(1)


train_data, test_data = train_test_split(dataset, test_size=0.2, random_state=42)

def save_split(data, split_name, output_dir):
    """
    Save the split data (train, test) into their respective directories.
    """
    split_dir = os.path.join(output_dir, split_name)
    os.makedirs(split_dir, exist_ok=True)

    for item in data:
        image_name = os.path.basename(item["image"])
        label_file = os.path.join(split_dir, image_name.replace(".jpg", ".txt"))

     
        shutil.copy(item["image"], os.path.join(split_dir, image_name))

    
        with open(label_file, "a") as f:  
            bbox = item["bbox"]
            label = item["label"]
            f.write(f"{label} {bbox[0]} {bbox[1]} {bbox[2]} {bbox[3]}\n")


save_split(train_data, "train", output_path)
save_split(test_data, "test", output_path)

print(f"Data split completed. Processed dataset saved in '{output_path}'")
# Out:
# Streaming output truncated to the last 5000 lines.
# Added bounding box: (86, 100, 121, 137)
# Line 2 in airplane_346.csv: 29 14 48 34
# Parsed parts: ['29', '14', '48', '34']
# Added bounding box: (29, 14, 48, 34)
# Line 3 in airplane_346.csv: 5 45 25 66
# Parsed parts: ['5', '45', '25', '66']
# Added bounding box: (5, 45, 25, 66)
# Processing airplane_699.csv, airplanes: 3
# Line 1 in airplane_699.csv: 12 67 56 102
# Parsed parts: ['12', '67', '56', '102']
# Added bounding box: (12, 67, 56, 102)
# Line 2 in airplane_699.csv: 55 43 93 83
# Parsed parts: ['55', '43', '93', '83']
# Added bounding box: (55, 43, 93, 83)
# Line 3 in airplane_699.csv: 102 14 137 52
# Parsed parts: ['102', '14', '137', '52']
# Added bounding box: (102, 14, 137, 52)
# Processing airplane_585.csv, airplanes: 2
# Line 1 in airplane_585.csv: 70 53 128 100
# Parsed parts: ['70', '53', '128', '100']
# Added bounding box: (70, 53, 128, 100)
# Line 2 in airplane_585.csv: 166 146 208 197
# Parsed parts: ['166', '146', '208', '197']
# Added bounding box: (166, 146, 208, 197)
# Processing airplane_091.csv, airplanes: 3
# Line 1 in airplane_091.csv: 14 83 36 103
# Parsed parts: ['14', '83', '36', '103']
# Added bounding box: (14, 83, 36, 103)
# Line 2 in airplane_091.csv: 36 139 54 161
# Parsed parts: ['36', '139', '54', '161']
# Added bounding box: (36, 139, 54, 161)
# Line 3 in airplane_091.csv: 228 117 252 151
# Parsed parts: ['228', '117', '252', '151']
# Added bounding box: (228, 117, 252, 151)
# Processing airplane_640.csv, airplanes: 1
# Line 1 in airplane_640.csv: 51 79 134 172
# Parsed parts: ['51', '79', '134', '172']
# Added bounding box: (51, 79, 134, 172)
# Processing airplane_485.csv, airplanes: 3
# Line 1 in airplane_485.csv: 38 38 95 80
# Parsed parts: ['38', '38', '95', '80']
# Added bounding box: (38, 38, 95, 80)
# Line 2 in airplane_485.csv: 194 4 227 25
# Parsed parts: ['194', '4', '227', '25']
# Added bounding box: (194, 4, 227, 25)
# Line 3 in airplane_485.csv: 214 25 245 51
# Parsed parts: ['214', '25', '245', '51']
# Added bounding box: (214, 25, 245, 51)
# Processing airplane_447.csv, airplanes: 3
# Line 1 in airplane_447.csv: 101 63 172 143
# Parsed parts: ['101', '63', '172', '143']
# Added bounding box: (101, 63, 172, 143)
# Line 2 in airplane_447.csv: 194 130 254 199
# Parsed parts: ['194', '130', '254', '199']
# Added bounding box: (194, 130, 254, 199)
# Line 3 in airplane_447.csv: 26 122 90 183
# Parsed parts: ['26', '122', '90', '183']
# Added bounding box: (26, 122, 90, 183)
# Processing airplane_071.csv, airplanes: 2
# Line 1 in airplane_071.csv: 178 37 209 64
# Parsed parts: ['178', '37', '209', '64']
# Added bounding box: (178, 37, 209, 64)
# Line 2 in airplane_071.csv: 184 75 240 118
# Parsed parts: ['184', '75', '240', '118']
# Added bounding box: (184, 75, 240, 118)
# Processing airplane_658.csv, airplanes: 6
# Line 1 in airplane_658.csv: 64 173 98 214
# Parsed parts: ['64', '173', '98', '214']
# Added bounding box: (64, 173, 98, 214)
# Line 2 in airplane_658.csv: 94 214 148 255
# Parsed parts: ['94', '214', '148', '255']
# Added bounding box: (94, 214, 148, 255)
# Line 3 in airplane_658.csv: 125 5 174 64
# Parsed parts: ['125', '5', '174', '64']
# Added bounding box: (125, 5, 174, 64)
# Line 4 in airplane_658.csv: 208 43 250 107
# Parsed parts: ['208', '43', '250', '107']
# Added bounding box: (208, 43, 250, 107)
# Line 5 in airplane_658.csv: 3 125 18 168
# Parsed parts: ['3', '125', '18', '168']
# Added bounding box: (3, 125, 18, 168)
# Line 6 in airplane_658.csv: 22 151 53 197
# Parsed parts: ['22', '151', '53', '197']
# Added bounding box: (22, 151, 53, 197)
# Processing airplane_062.csv, airplanes: 1
# Line 1 in airplane_062.csv: 85 104 201 181
# Parsed parts: ['85', '104', '201', '181']
# Added bounding box: (85, 104, 201, 181)
# Processing airplane_128.csv, airplanes: 3
# Line 1 in airplane_128.csv: 29 25 98 77
# Parsed parts: ['29', '25', '98', '77']
# Added bounding box: (29, 25, 98, 77)
# Line 2 in airplane_128.csv: 69 84 145 145
# Parsed parts: ['69', '84', '145', '145']
# Added bounding box: (69, 84, 145, 145)
# Line 3 in airplane_128.csv: 118 155 193 225
# Parsed parts: ['118', '155', '193', '225']
# Added bounding box: (118, 155, 193, 225)
# Processing airplane_252.csv, airplanes: 6
# Line 1 in airplane_252.csv: 59 94 117 147
# Parsed parts: ['59', '94', '117', '147']
# Added bounding box: (59, 94, 117, 147)
# Line 2 in airplane_252.csv: 89 150 129 186
# Parsed parts: ['89', '150', '129', '186']
# Added bounding box: (89, 150, 129, 186)
# Line 3 in airplane_252.csv: 122 199 172 238
# Parsed parts: ['122', '199', '172', '238']
# Added bounding box: (122, 199, 172, 238)
# Line 4 in airplane_252.csv: 212 75 228 99
# Parsed parts: ['212', '75', '228', '99']
# Added bounding box: (212, 75, 228, 99)
# Line 5 in airplane_252.csv: 35 55 82 94
# Parsed parts: ['35', '55', '82', '94']
# Added bounding box: (35, 55, 82, 94)
# Line 6 in airplane_252.csv: 6 16 54 61
# Parsed parts: ['6', '16', '54', '61']
# Added bounding box: (6, 16, 54, 61)
# Processing 428492.csv, airplanes: 1
# Line 1 in 428492.csv: 106 110 144 148
# Parsed parts: ['106', '110', '144', '148']
# Added bounding box: (106, 110, 144, 148)
# Processing airplane_448.csv, airplanes: 5
# Line 1 in airplane_448.csv: 167 67 194 89
# Parsed parts: ['167', '67', '194', '89']
# Added bounding box: (167, 67, 194, 89)
# Line 2 in airplane_448.csv: 67 64 89 88
# Parsed parts: ['67', '64', '89', '88']
# Added bounding box: (67, 64, 89, 88)
# Line 3 in airplane_448.csv: 166 181 192 203
# Parsed parts: ['166', '181', '192', '203']
# Added bounding box: (166, 181, 192, 203)
# Line 4 in airplane_448.csv: 47 142 77 167
# Parsed parts: ['47', '142', '77', '167']
# Added bounding box: (47, 142, 77, 167)
# Line 5 in airplane_448.csv: 65 202 91 225
# Parsed parts: ['65', '202', '91', '225']
# Added bounding box: (65, 202, 91, 225)
# Processing airplane_049.csv, airplanes: 1
# Line 1 in airplane_049.csv: 73 54 170 142
# Parsed parts: ['73', '54', '170', '142']
# Added bounding box: (73, 54, 170, 142)
# Processing airplane_427.csv, airplanes: 3
# Line 1 in airplane_427.csv: 6 136 104 215
# Parsed parts: ['6', '136', '104', '215']
# Added bounding box: (6, 136, 104, 215)
# Line 2 in airplane_427.csv: 162 142 252 224
# Parsed parts: ['162', '142', '252', '224']
# Added bounding box: (162, 142, 252, 224)
# Line 3 in airplane_427.csv: 5 2 84 93
# Parsed parts: ['5', '2', '84', '93']
# Added bounding box: (5, 2, 84, 93)
# Processing airplane_372.csv, airplanes: 3
# Line 1 in airplane_372.csv: 74 147 108 185
# Parsed parts: ['74', '147', '108', '185']
# Added bounding box: (74, 147, 108, 185)
# Line 2 in airplane_372.csv: 130 203 162 233
# Parsed parts: ['130', '203', '162', '233']
# Added bounding box: (130, 203, 162, 233)
# Line 3 in airplane_372.csv: 164 148 196 178
# Parsed parts: ['164', '148', '196', '178']
# Added bounding box: (164, 148, 196, 178)
# Processing airplane_354.csv, airplanes: 2
# Line 1 in airplane_354.csv: 45 44 108 99
# Parsed parts: ['45', '44', '108', '99']
# Added bounding box: (45, 44, 108, 99)
# Line 2 in airplane_354.csv: 151 155 223 222
# Parsed parts: ['151', '155', '223', '222']
# Added bounding box: (151, 155, 223, 222)
# Processing airplane_677.csv, airplanes: 2
# Line 1 in airplane_677.csv: 32 115 125 219
# Parsed parts: ['32', '115', '125', '219']
# Added bounding box: (32, 115, 125, 219)
# Line 2 in airplane_677.csv: 161 54 226 138
# Parsed parts: ['161', '54', '226', '138']
# Added bounding box: (161, 54, 226, 138)
# Processing airplane_671.csv, airplanes: 2
# Line 1 in airplane_671.csv: 47 94 123 166
# Parsed parts: ['47', '94', '123', '166']
# Added bounding box: (47, 94, 123, 166)
# Line 2 in airplane_671.csv: 124 45 204 121
# Parsed parts: ['124', '45', '204', '121']
# Added bounding box: (124, 45, 204, 121)
# Processing airplane_390.csv, airplanes: 2
# Line 1 in airplane_390.csv: 126 193 175 238
# Parsed parts: ['126', '193', '175', '238']
# Added bounding box: (126, 193, 175, 238)
# Line 2 in airplane_390.csv: 198 92 242 129
# Parsed parts: ['198', '92', '242', '129']
# Added bounding box: (198, 92, 242, 129)
# Processing airplane_080.csv, airplanes: 1
# Line 1 in airplane_080.csv: 68 132 174 244
# Parsed parts: ['68', '132', '174', '244']
# Added bounding box: (68, 132, 174, 244)
# Processing airplane_556.csv, airplanes: 8
# Line 1 in airplane_556.csv: 96 153 124 180
# Parsed parts: ['96', '153', '124', '180']
# Added bounding box: (96, 153, 124, 180)
# Line 2 in airplane_556.csv: 128 172 159 197
# Parsed parts: ['128', '172', '159', '197']
# Added bounding box: (128, 172, 159, 197)
# Line 3 in airplane_556.csv: 159 197 183 219
# Parsed parts: ['159', '197', '183', '219']
# Added bounding box: (159, 197, 183, 219)
# Line 4 in airplane_556.csv: 184 213 217 241
# Parsed parts: ['184', '213', '217', '241']
# Added bounding box: (184, 213, 217, 241)
# Line 5 in airplane_556.csv: 60 125 83 149
# Parsed parts: ['60', '125', '83', '149']
# Added bounding box: (60, 125, 83, 149)
# Line 6 in airplane_556.csv: 46 108 63 128
# Parsed parts: ['46', '108', '63', '128']
# Added bounding box: (46, 108, 63, 128)
# Line 7 in airplane_556.csv: 16 82 43 110
# Parsed parts: ['16', '82', '43', '110']
# Added bounding box: (16, 82, 43, 110)
# Line 8 in airplane_556.csv: 4 71 20 98
# Parsed parts: ['4', '71', '20', '98']
# Added bounding box: (4, 71, 20, 98)
# Processing airplane_165.csv, airplanes: 2
# Line 1 in airplane_165.csv: 58 178 119 243
# Parsed parts: ['58', '178', '119', '243']
# Added bounding box: (58, 178, 119, 243)
# Line 2 in airplane_165.csv: 210 83 244 117
# Parsed parts: ['210', '83', '244', '117']
# Added bounding box: (210, 83, 244, 117)
# Processing airplane_662.csv, airplanes: 1
# Line 1 in airplane_662.csv: 84 7 129 48
# Parsed parts: ['84', '7', '129', '48']
# Added bounding box: (84, 7, 129, 48)
# Processing airplane_592.csv, airplanes: 2
# Line 1 in airplane_592.csv: 64 186 127 245
# Parsed parts: ['64', '186', '127', '245']
# Added bounding box: (64, 186, 127, 245)
# Line 2 in airplane_592.csv: 183 4 248 63
# Parsed parts: ['183', '4', '248', '63']
# Added bounding box: (183, 4, 248, 63)
# Processing airplane_101.csv, airplanes: 2
# Line 1 in airplane_101.csv: 76 48 150 124
# Parsed parts: ['76', '48', '150', '124']
# Added bounding box: (76, 48, 150, 124)
# Line 2 in airplane_101.csv: 64 137 140 213
# Parsed parts: ['64', '137', '140', '213']
# Added bounding box: (64, 137, 140, 213)
# Processing airplane_180.csv, airplanes: 2
# Line 1 in airplane_180.csv: 114 56 157 95
# Parsed parts: ['114', '56', '157', '95']
# Added bounding box: (114, 56, 157, 95)
# Line 2 in airplane_180.csv: 3 153 25 176
# Parsed parts: ['3', '153', '25', '176']
# Added bounding box: (3, 153, 25, 176)
# Processing hotanairport5.csv, airplanes: 13
# Line 1 in hotanairport5.csv: 55 33 63 44
# Parsed parts: ['55', '33', '63', '44']
# Added bounding box: (55, 33, 63, 44)
# Line 2 in hotanairport5.csv: 63 37 70 48
# Parsed parts: ['63', '37', '70', '48']
# Added bounding box: (63, 37, 70, 48)
# Line 3 in hotanairport5.csv: 71 41 75 51
# Parsed parts: ['71', '41', '75', '51']
# Added bounding box: (71, 41, 75, 51)
# Line 4 in hotanairport5.csv: 77 42 83 53
# Parsed parts: ['77', '42', '83', '53']
# Added bounding box: (77, 42, 83, 53)
# Line 5 in hotanairport5.csv: 83 45 90 55
# Parsed parts: ['83', '45', '90', '55']
# Added bounding box: (83, 45, 90, 55)
# Line 6 in hotanairport5.csv: 90 48 100 59
# Parsed parts: ['90', '48', '100', '59']
# Added bounding box: (90, 48, 100, 59)
# Line 7 in hotanairport5.csv: 98 50 105 63
# Parsed parts: ['98', '50', '105', '63']
# Added bounding box: (98, 50, 105, 63)
# Line 8 in hotanairport5.csv: 106 53 111 63
# Parsed parts: ['106', '53', '111', '63']
# Added bounding box: (106, 53, 111, 63)
# Line 9 in hotanairport5.csv: 110 56 117 66
# Parsed parts: ['110', '56', '117', '66']
# Added bounding box: (110, 56, 117, 66)
# Line 10 in hotanairport5.csv: 119 58 125 68
# Parsed parts: ['119', '58', '125', '68']
# Added bounding box: (119, 58, 125, 68)
# Line 11 in hotanairport5.csv: 125 58 132 71
# Parsed parts: ['125', '58', '132', '71']
# Added bounding box: (125, 58, 132, 71)
# Line 12 in hotanairport5.csv: 132 66 137 74
# Parsed parts: ['132', '66', '137', '74']
# Added bounding box: (132, 66, 137, 74)
# Line 13 in hotanairport5.csv: 140 63 146 78
# Parsed parts: ['140', '63', '146', '78']
# Added bounding box: (140, 63, 146, 78)
# Processing airplane_583.csv, airplanes: 3
# Line 1 in airplane_583.csv: 20 56 81 120
# Parsed parts: ['20', '56', '81', '120']
# Added bounding box: (20, 56, 81, 120)
# Line 2 in airplane_583.csv: 124 23 191 79
# Parsed parts: ['124', '23', '191', '79']
# Added bounding box: (124, 23, 191, 79)
# Line 3 in airplane_583.csv: 210 177 250 242
# Parsed parts: ['210', '177', '250', '242']
# Added bounding box: (210, 177, 250, 242)
# Processing airplane_017.csv, airplanes: 2
# Line 1 in airplane_017.csv: 45 86 106 153
# Parsed parts: ['45', '86', '106', '153']
# Added bounding box: (45, 86, 106, 153)
# Line 2 in airplane_017.csv: 133 64 193 125
# Parsed parts: ['133', '64', '193', '125']
# Added bounding box: (133, 64, 193, 125)
# Processing airplane_545.csv, airplanes: 2
# Line 1 in airplane_545.csv: 55 26 145 83
# Parsed parts: ['55', '26', '145', '83']
# Added bounding box: (55, 26, 145, 83)
# Line 2 in airplane_545.csv: 105 88 198 161
# Parsed parts: ['105', '88', '198', '161']
# Added bounding box: (105, 88, 198, 161)
# Processing airplane_052.csv, airplanes: 2
# Line 1 in airplane_052.csv: 106 4 135 38
# Parsed parts: ['106', '4', '135', '38']
# Added bounding box: (106, 4, 135, 38)
# Line 2 in airplane_052.csv: 25 52 67 89
# Parsed parts: ['25', '52', '67', '89']
# Added bounding box: (25, 52, 67, 89)
# Processing airplane_454.csv, airplanes: 2
# Line 1 in airplane_454.csv: 3 58 41 110
# Parsed parts: ['3', '58', '41', '110']
# Added bounding box: (3, 58, 41, 110)
# Line 2 in airplane_454.csv: 37 87 65 114
# Parsed parts: ['37', '87', '65', '114']
# Added bounding box: (37, 87, 65, 114)
# Processing airplane_673.csv, airplanes: 1
# Line 1 in airplane_673.csv: 43 49 201 188
# Parsed parts: ['43', '49', '201', '188']
# Added bounding box: (43, 49, 201, 188)
# Processing airplane_394.csv, airplanes: 2
# Line 1 in airplane_394.csv: 134 105 174 146
# Parsed parts: ['134', '105', '174', '146']
# Added bounding box: (134, 105, 174, 146)
# Line 2 in airplane_394.csv: 220 2 256 33
# Parsed parts: ['220', '2', '256', '33']
# Added bounding box: (220, 2, 256, 33)
# Processing airplane_471.csv, airplanes: 3
# Line 1 in airplane_471.csv: 43 51 64 73
# Parsed parts: ['43', '51', '64', '73']
# Added bounding box: (43, 51, 64, 73)
# Line 2 in airplane_471.csv: 45 13 66 35
# Parsed parts: ['45', '13', '66', '35']
# Added bounding box: (45, 13, 66, 35)
# Line 3 in airplane_471.csv: 76 35 96 59
# Parsed parts: ['76', '35', '96', '59']
# Added bounding box: (76, 35, 96, 59)
# Processing airplane_034.csv, airplanes: 1
# Line 1 in airplane_034.csv: 166 84 253 186
# Parsed parts: ['166', '84', '253', '186']
# Added bounding box: (166, 84, 253, 186)
# Processing airplane_216.csv, airplanes: 6
# Line 1 in airplane_216.csv: 36 80 60 110
# Parsed parts: ['36', '80', '60', '110']
# Added bounding box: (36, 80, 60, 110)
# Line 2 in airplane_216.csv: 86 71 116 97
# Parsed parts: ['86', '71', '116', '97']
# Added bounding box: (86, 71, 116, 97)
# Line 3 in airplane_216.csv: 128 74 160 101
# Parsed parts: ['128', '74', '160', '101']
# Added bounding box: (128, 74, 160, 101)
# Line 4 in airplane_216.csv: 145 106 184 141
# Parsed parts: ['145', '106', '184', '141']
# Added bounding box: (145, 106, 184, 141)
# Line 5 in airplane_216.csv: 201 87 246 137
# Parsed parts: ['201', '87', '246', '137']
# Added bounding box: (201, 87, 246, 137)
# Line 6 in airplane_216.csv: 155 157 192 183
# Parsed parts: ['155', '157', '192', '183']
# Added bounding box: (155, 157, 192, 183)
# Processing airplane_289.csv, airplanes: 2
# Line 1 in airplane_289.csv: 47 19 129 136
# Parsed parts: ['47', '19', '129', '136']
# Added bounding box: (47, 19, 129, 136)
# Line 2 in airplane_289.csv: 167 69 252 181
# Parsed parts: ['167', '69', '252', '181']
# Added bounding box: (167, 69, 252, 181)
# Processing airplane_627.csv, airplanes: 1
# Line 1 in airplane_627.csv: 86 43 185 162
# Parsed parts: ['86', '43', '185', '162']
# Added bounding box: (86, 43, 185, 162)
# Processing airplane_508.csv, airplanes: 1
# Line 1 in airplane_508.csv: 78 68 160 149
# Parsed parts: ['78', '68', '160', '149']
# Added bounding box: (78, 68, 160, 149)
# Processing airplane_473.csv, airplanes: 10
# Line 1 in airplane_473.csv: 36 116 72 149
# Parsed parts: ['36', '116', '72', '149']
# Added bounding box: (36, 116, 72, 149)
# Line 2 in airplane_473.csv: 134 114 159 134
# Parsed parts: ['134', '114', '159', '134']
# Added bounding box: (134, 114, 159, 134)
# Line 3 in airplane_473.csv: 108 70 127 90
# Parsed parts: ['108', '70', '127', '90']
# Added bounding box: (108, 70, 127, 90)
# Line 4 in airplane_473.csv: 112 58 133 74
# Parsed parts: ['112', '58', '133', '74']
# Added bounding box: (112, 58, 133, 74)
# Line 5 in airplane_473.csv: 124 51 133 65
# Parsed parts: ['124', '51', '133', '65']
# Added bounding box: (124, 51, 133, 65)
# Line 6 in airplane_473.csv: 123 39 142 52
# Parsed parts: ['123', '39', '142', '52']
# Added bounding box: (123, 39, 142, 52)
# Line 7 in airplane_473.csv: 171 48 187 64
# Parsed parts: ['171', '48', '187', '64']
# Added bounding box: (171, 48, 187, 64)
# Line 8 in airplane_473.csv: 166 67 181 77
# Parsed parts: ['166', '67', '181', '77']
# Added bounding box: (166, 67, 181, 77)
# Line 9 in airplane_473.csv: 155 77 170 89
# Parsed parts: ['155', '77', '170', '89']
# Added bounding box: (155, 77, 170, 89)
# Line 10 in airplane_473.csv: 151 87 170 104
# Parsed parts: ['151', '87', '170', '104']
# Added bounding box: (151, 87, 170, 104)
# Processing airplane_132.csv, airplanes: 5
# Line 1 in airplane_132.csv: 59 163 99 205
# Parsed parts: ['59', '163', '99', '205']
# Added bounding box: (59, 163, 99, 205)
# Line 2 in airplane_132.csv: 100 78 117 97
# Parsed parts: ['100', '78', '117', '97']
# Added bounding box: (100, 78, 117, 97)
# Line 3 in airplane_132.csv: 115 61 133 81
# Parsed parts: ['115', '61', '133', '81']
# Added bounding box: (115, 61, 133, 81)
# Line 4 in airplane_132.csv: 223 104 256 157
# Parsed parts: ['223', '104', '256', '157']
# Added bounding box: (223, 104, 256, 157)
# Line 5 in airplane_132.csv: 219 3 255 19
# Parsed parts: ['219', '3', '255', '19']
# Added bounding box: (219, 3, 255, 19)
# Processing airplane_100.csv, airplanes: 2
# Line 1 in airplane_100.csv: 101 42 148 83
# Parsed parts: ['101', '42', '148', '83']
# Added bounding box: (101, 42, 148, 83)
# Line 2 in airplane_100.csv: 130 135 175 185
# Parsed parts: ['130', '135', '175', '185']
# Added bounding box: (130, 135, 175, 185)
# Processing airplane_487.csv, airplanes: 5
# Line 1 in airplane_487.csv: 113 150 165 196
# Parsed parts: ['113', '150', '165', '196']
# Added bounding box: (113, 150, 165, 196)
# Line 2 in airplane_487.csv: 168 147 213 173
# Parsed parts: ['168', '147', '213', '173']
# Added bounding box: (168, 147, 213, 173)
# Line 3 in airplane_487.csv: 213 132 256 172
# Parsed parts: ['213', '132', '256', '172']
# Added bounding box: (213, 132, 256, 172)
# Line 4 in airplane_487.csv: 21 106 84 152
# Parsed parts: ['21', '106', '84', '152']
# Added bounding box: (21, 106, 84, 152)
# Line 5 in airplane_487.csv: 5 50 59 97
# Parsed parts: ['5', '50', '59', '97']
# Added bounding box: (5, 50, 59, 97)
# Processing airplane_075.csv, airplanes: 7
# Line 1 in airplane_075.csv: 77 14 127 68
# Parsed parts: ['77', '14', '127', '68']
# Added bounding box: (77, 14, 127, 68)
# Line 2 in airplane_075.csv: 183 132 234 190
# Parsed parts: ['183', '132', '234', '190']
# Added bounding box: (183, 132, 234, 190)
# Line 3 in airplane_075.csv: 218 195 251 231
# Parsed parts: ['218', '195', '251', '231']
# Added bounding box: (218, 195, 251, 231)
# Line 4 in airplane_075.csv: 3 114 43 166
# Parsed parts: ['3', '114', '43', '166']
# Added bounding box: (3, 114, 43, 166)
# Line 5 in airplane_075.csv: 39 162 89 215
# Parsed parts: ['39', '162', '89', '215']
# Added bounding box: (39, 162, 89, 215)
# Line 6 in airplane_075.csv: 4 202 19 234
# Parsed parts: ['4', '202', '19', '234']
# Added bounding box: (4, 202, 19, 234)
# Line 7 in airplane_075.csv: 15 222 58 254
# Parsed parts: ['15', '222', '58', '254']
# Added bounding box: (15, 222, 58, 254)
# Processing airplane_195.csv, airplanes: 2
# Line 1 in airplane_195.csv: 58 93 136 171
# Parsed parts: ['58', '93', '136', '171']
# Added bounding box: (58, 93, 136, 171)
# Line 2 in airplane_195.csv: 164 63 235 148
# Parsed parts: ['164', '63', '235', '148']
# Added bounding box: (164, 63, 235, 148)
# Processing 428472.csv, airplanes: 3
# Line 1 in 428472.csv: 115 50 149 78
# Parsed parts: ['115', '50', '149', '78']
# Added bounding box: (115, 50, 149, 78)
# Line 2 in 428472.csv: 23 120 56 155
# Parsed parts: ['23', '120', '56', '155']
# Added bounding box: (23, 120, 56, 155)
# Line 3 in 428472.csv: 217 209 245 241
# Parsed parts: ['217', '209', '245', '241']
# Added bounding box: (217, 209, 245, 241)
# Processing airplane_246.csv, airplanes: 4
# Line 1 in airplane_246.csv: 12 42 64 78
# Parsed parts: ['12', '42', '64', '78']
# Added bounding box: (12, 42, 64, 78)
# Line 2 in airplane_246.csv: 2 74 39 108
# Parsed parts: ['2', '74', '39', '108']
# Added bounding box: (2, 74, 39, 108)
# Line 3 in airplane_246.csv: 3 216 24 247
# Parsed parts: ['3', '216', '24', '247']
# Added bounding box: (3, 216, 24, 247)
# Line 4 in airplane_246.csv: 30 1 49 22
# Parsed parts: ['30', '1', '49', '22']
# Added bounding box: (30, 1, 49, 22)
# Processing airplane_632.csv, airplanes: 4
# Line 1 in airplane_632.csv: 19 32 105 94
# Parsed parts: ['19', '32', '105', '94']
# Added bounding box: (19, 32, 105, 94)
# Line 2 in airplane_632.csv: 111 42 185 107
# Parsed parts: ['111', '42', '185', '107']
# Added bounding box: (111, 42, 185, 107)
# Line 3 in airplane_632.csv: 146 11 205 50
# Parsed parts: ['146', '11', '205', '50']
# Added bounding box: (146, 11, 205, 50)
# Line 4 in airplane_632.csv: 94 162 150 212
# Parsed parts: ['94', '162', '150', '212']
# Added bounding box: (94, 162, 150, 212)
# Processing airplane_653.csv, airplanes: 1
# Line 1 in airplane_653.csv: 102 19 133 51
# Parsed parts: ['102', '19', '133', '51']
# Added bounding box: (102, 19, 133, 51)
# Processing airplane_323.csv, airplanes: 1
# Line 1 in airplane_323.csv: 77 68 168 168
# Parsed parts: ['77', '68', '168', '168']
# Added bounding box: (77, 68, 168, 168)
# Processing airplane_358.csv, airplanes: 1
# Line 1 in airplane_358.csv: 65 33 176 155
# Parsed parts: ['65', '33', '176', '155']
# Added bounding box: (65, 33, 176, 155)
# Processing airplane_334.csv, airplanes: 4
# Line 1 in airplane_334.csv: 166 179 201 209
# Parsed parts: ['166', '179', '201', '209']
# Added bounding box: (166, 179, 201, 209)
# Line 2 in airplane_334.csv: 97 178 110 196
# Parsed parts: ['97', '178', '110', '196']
# Added bounding box: (97, 178, 110, 196)
# Line 3 in airplane_334.csv: 116 176 137 195
# Parsed parts: ['116', '176', '137', '195']
# Added bounding box: (116, 176, 137, 195)
# Line 4 in airplane_334.csv: 98 213 144 254
# Parsed parts: ['98', '213', '144', '254']
# Added bounding box: (98, 213, 144, 254)
# Processing airplane_261.csv, airplanes: 2
# Line 1 in airplane_261.csv: 33 194 66 235
# Parsed parts: ['33', '194', '66', '235']
# Added bounding box: (33, 194, 66, 235)
# Line 2 in airplane_261.csv: 129 130 143 142
# Parsed parts: ['129', '130', '143', '142']
# Added bounding box: (129, 130, 143, 142)
# Processing airplane_586.csv, airplanes: 6
# Line 1 in airplane_586.csv: 22 103 70 151
# Parsed parts: ['22', '103', '70', '151']
# Added bounding box: (22, 103, 70, 151)
# Line 2 in airplane_586.csv: 62 56 111 102
# Parsed parts: ['62', '56', '111', '102']
# Added bounding box: (62, 56, 111, 102)
# Line 3 in airplane_586.csv: 101 25 134 59
# Parsed parts: ['101', '25', '134', '59']
# Added bounding box: (101, 25, 134, 59)
# Line 4 in airplane_586.csv: 129 3 164 30
# Parsed parts: ['129', '3', '164', '30']
# Added bounding box: (129, 3, 164, 30)
# Line 5 in airplane_586.csv: 190 188 226 230
# Parsed parts: ['190', '188', '226', '230']
# Added bounding box: (190, 188, 226, 230)
# Line 6 in airplane_586.csv: 47 208 91 251
# Parsed parts: ['47', '208', '91', '251']
# Added bounding box: (47, 208, 91, 251)
# Processing airplane_611.csv, airplanes: 2
# Line 1 in airplane_611.csv: 44 91 120 174
# Parsed parts: ['44', '91', '120', '174']
# Added bounding box: (44, 91, 120, 174)
# Line 2 in airplane_611.csv: 153 111 214 204
# Parsed parts: ['153', '111', '214', '204']
# Added bounding box: (153, 111, 214, 204)
# Processing airplane_087.csv, airplanes: 1
# Line 1 in airplane_087.csv: 71 74 185 181
# Parsed parts: ['71', '74', '185', '181']
# Added bounding box: (71, 74, 185, 181)
# Processing airplane_418.csv, airplanes: 6
# Line 1 in airplane_418.csv: 41 11 85 54
# Parsed parts: ['41', '11', '85', '54']
# Added bounding box: (41, 11, 85, 54)
# Line 2 in airplane_418.csv: 44 62 84 108
# Parsed parts: ['44', '62', '84', '108']
# Added bounding box: (44, 62, 84, 108)
# Line 3 in airplane_418.csv: 45 111 87 160
# Parsed parts: ['45', '111', '87', '160']
# Added bounding box: (45, 111, 87, 160)
# Line 4 in airplane_418.csv: 45 165 89 213
# Parsed parts: ['45', '165', '89', '213']
# Added bounding box: (45, 165, 89, 213)
# Line 5 in airplane_418.csv: 46 216 94 256
# Parsed parts: ['46', '216', '94', '256']
# Added bounding box: (46, 216, 94, 256)
# Line 6 in airplane_418.csv: 183 164 246 241
# Parsed parts: ['183', '164', '246', '241']
# Added bounding box: (183, 164, 246, 241)
# Processing 428461.csv, airplanes: 5
# Line 1 in 428461.csv: 176 12 207 41
# Parsed parts: ['176', '12', '207', '41']
# Added bounding box: (176, 12, 207, 41)
# Line 2 in 428461.csv: 155 47 188 82
# Parsed parts: ['155', '47', '188', '82']
# Added bounding box: (155, 47, 188, 82)
# Line 3 in 428461.csv: 86 125 118 160
# Parsed parts: ['86', '125', '118', '160']
# Added bounding box: (86, 125, 118, 160)
# Line 4 in 428461.csv: 54 108 83 134
# Parsed parts: ['54', '108', '83', '134']
# Added bounding box: (54, 108, 83, 134)
# Line 5 in 428461.csv: 0 65 22 104
# Parsed parts: ['0', '65', '22', '104']
# Added bounding box: (0, 65, 22, 104)
# Processing airplane_110.csv, airplanes: 2
# Line 1 in airplane_110.csv: 3 19 58 71
# Parsed parts: ['3', '19', '58', '71']
# Added bounding box: (3, 19, 58, 71)
# Line 2 in airplane_110.csv: 187 175 250 239
# Parsed parts: ['187', '175', '250', '239']
# Added bounding box: (187, 175, 250, 239)
# Processing airplane_155.csv, airplanes: 2
# Line 1 in airplane_155.csv: 103 182 153 220
# Parsed parts: ['103', '182', '153', '220']
# Added bounding box: (103, 182, 153, 220)
# Line 2 in airplane_155.csv: 86 49 111 68
# Parsed parts: ['86', '49', '111', '68']
# Added bounding box: (86, 49, 111, 68)
# Processing airplane_125.csv, airplanes: 5
# Line 1 in airplane_125.csv: 110 1 165 19
# Parsed parts: ['110', '1', '165', '19']
# Added bounding box: (110, 1, 165, 19)
# Line 2 in airplane_125.csv: 145 20 189 49
# Parsed parts: ['145', '20', '189', '49']
# Added bounding box: (145, 20, 189, 49)
# Line 3 in airplane_125.csv: 162 62 205 100
# Parsed parts: ['162', '62', '205', '100']
# Added bounding box: (162, 62, 205, 100)
# Line 4 in airplane_125.csv: 203 99 249 142
# Parsed parts: ['203', '99', '249', '142']
# Added bounding box: (203, 99, 249, 142)
# Line 5 in airplane_125.csv: 201 161 250 202
# Parsed parts: ['201', '161', '250', '202']
# Added bounding box: (201, 161, 250, 202)
# Processing airplane_565.csv, airplanes: 1
# Line 1 in airplane_565.csv: 41 51 111 131
# Parsed parts: ['41', '51', '111', '131']
# Added bounding box: (41, 51, 111, 131)
# Processing airplane_384.csv, airplanes: 3
# Line 1 in airplane_384.csv: 80 133 111 172
# Parsed parts: ['80', '133', '111', '172']
# Added bounding box: (80, 133, 111, 172)
# Line 2 in airplane_384.csv: 203 43 234 84
# Parsed parts: ['203', '43', '234', '84']
# Added bounding box: (203, 43, 234, 84)
# Line 3 in airplane_384.csv: 222 84 256 131
# Parsed parts: ['222', '84', '256', '131']
# Added bounding box: (222, 84, 256, 131)
# Processing airplane_103.csv, airplanes: 3
# Line 1 in airplane_103.csv: 39 4 94 46
# Parsed parts: ['39', '4', '94', '46']
# Added bounding box: (39, 4, 94, 46)
# Line 2 in airplane_103.csv: 99 7 149 59
# Parsed parts: ['99', '7', '149', '59']
# Added bounding box: (99, 7, 149, 59)
# Line 3 in airplane_103.csv: 178 68 238 122
# Parsed parts: ['178', '68', '238', '122']
# Added bounding box: (178, 68, 238, 122)
# Processing airplane_201.csv, airplanes: 26
# Line 1 in airplane_201.csv: 22 78 31 90
# Parsed parts: ['22', '78', '31', '90']
# Added bounding box: (22, 78, 31, 90)
# Line 2 in airplane_201.csv: 29 69 48 81
# Parsed parts: ['29', '69', '48', '81']
# Added bounding box: (29, 69, 48, 81)
# Line 3 in airplane_201.csv: 44 65 59 76
# Parsed parts: ['44', '65', '59', '76']
# Added bounding box: (44, 65, 59, 76)
# Line 4 in airplane_201.csv: 58 57 68 70
# Parsed parts: ['58', '57', '68', '70']
# Added bounding box: (58, 57, 68, 70)
# Line 5 in airplane_201.csv: 122 16 138 26
# Parsed parts: ['122', '16', '138', '26']
# Added bounding box: (122, 16, 138, 26)
# Line 6 in airplane_201.csv: 134 9 146 21
# Parsed parts: ['134', '9', '146', '21']
# Added bounding box: (134, 9, 146, 21)
# Line 7 in airplane_201.csv: 93 35 102 46
# Parsed parts: ['93', '35', '102', '46']
# Added bounding box: (93, 35, 102, 46)
# Line 8 in airplane_201.csv: 79 41 93 56
# Parsed parts: ['79', '41', '93', '56']
# Added bounding box: (79, 41, 93, 56)
# Line 9 in airplane_201.csv: 69 48 79 59
# Parsed parts: ['69', '48', '79', '59']
# Added bounding box: (69, 48, 79, 59)
# Line 10 in airplane_201.csv: 27 110 39 121
# Parsed parts: ['27', '110', '39', '121']
# Added bounding box: (27, 110, 39, 121)
# Line 11 in airplane_201.csv: 38 102 48 111
# Parsed parts: ['38', '102', '48', '111']
# Added bounding box: (38, 102, 48, 111)
# Line 12 in airplane_201.csv: 48 97 62 105
# Parsed parts: ['48', '97', '62', '105']
# Added bounding box: (48, 97, 62, 105)
# Line 13 in airplane_201.csv: 61 89 76 97
# Parsed parts: ['61', '89', '76', '97']
# Added bounding box: (61, 89, 76, 97)
# Line 14 in airplane_201.csv: 73 82 86 91
# Parsed parts: ['73', '82', '86', '91']
# Added bounding box: (73, 82, 86, 91)
# Line 15 in airplane_201.csv: 87 75 96 84
# Parsed parts: ['87', '75', '96', '84']
# Added bounding box: (87, 75, 96, 84)
# Line 16 in airplane_201.csv: 106 69 118 79
# Parsed parts: ['106', '69', '118', '79']
# Added bounding box: (106, 69, 118, 79)
# Line 17 in airplane_201.csv: 118 53 133 65
# Parsed parts: ['118', '53', '133', '65']
# Added bounding box: (118, 53, 133, 65)
# Line 18 in airplane_201.csv: 133 47 145 58
# Parsed parts: ['133', '47', '145', '58']
# Added bounding box: (133, 47, 145, 58)
# Line 19 in airplane_201.csv: 144 39 154 48
# Parsed parts: ['144', '39', '154', '48']
# Added bounding box: (144, 39, 154, 48)
# Line 20 in airplane_201.csv: 116 238 127 253
# Parsed parts: ['116', '238', '127', '253']
# Added bounding box: (116, 238, 127, 253)
# Line 21 in airplane_201.csv: 126 232 143 248
# Parsed parts: ['126', '232', '143', '248']
# Added bounding box: (126, 232, 143, 248)
# Line 22 in airplane_201.csv: 136 225 152 241
# Parsed parts: ['136', '225', '152', '241']
# Added bounding box: (136, 225, 152, 241)
# Line 23 in airplane_201.csv: 154 216 164 226
# Parsed parts: ['154', '216', '164', '226']
# Added bounding box: (154, 216, 164, 226)
# Line 24 in airplane_201.csv: 165 209 179 219
# Parsed parts: ['165', '209', '179', '219']
# Added bounding box: (165, 209, 179, 219)
# Line 25 in airplane_201.csv: 166 220 174 230
# Parsed parts: ['166', '220', '174', '230']
# Added bounding box: (166, 220, 174, 230)
# Line 26 in airplane_201.csv: 152 229 165 237
# Parsed parts: ['152', '229', '165', '237']
# Added bounding box: (152, 229, 165, 237)
# Processing airplane_350.csv, airplanes: 4
# Line 1 in airplane_350.csv: 93 43 118 66
# Parsed parts: ['93', '43', '118', '66']
# Added bounding box: (93, 43, 118, 66)
# Line 2 in airplane_350.csv: 99 81 128 103
# Parsed parts: ['99', '81', '128', '103']
# Added bounding box: (99, 81, 128, 103)
# Line 3 in airplane_350.csv: 104 129 128 151
# Parsed parts: ['104', '129', '128', '151']
# Added bounding box: (104, 129, 128, 151)
# Line 4 in airplane_350.csv: 117 170 137 188
# Parsed parts: ['117', '170', '137', '188']
# Added bounding box: (117, 170, 137, 188)
# Processing airplane_494.csv, airplanes: 1
# Line 1 in airplane_494.csv: 13 132 101 204
# Parsed parts: ['13', '132', '101', '204']
# Added bounding box: (13, 132, 101, 204)
# Processing airplane_550.csv, airplanes: 3
# Line 1 in airplane_550.csv: 44 129 110 182
# Parsed parts: ['44', '129', '110', '182']
# Added bounding box: (44, 129, 110, 182)
# Line 2 in airplane_550.csv: 52 75 112 115
# Parsed parts: ['52', '75', '112', '115']
# Added bounding box: (52, 75, 112, 115)
# Line 3 in airplane_550.csv: 59 19 119 72
# Parsed parts: ['59', '19', '119', '72']
# Added bounding box: (59, 19, 119, 72)
# Processing airplane_043.csv, airplanes: 4
# Line 1 in airplane_043.csv: 109 29 130 56
# Parsed parts: ['109', '29', '130', '56']
# Added bounding box: (109, 29, 130, 56)
# Line 2 in airplane_043.csv: 108 69 129 97
# Parsed parts: ['108', '69', '129', '97']
# Added bounding box: (108, 69, 129, 97)
# Line 3 in airplane_043.csv: 104 110 126 138
# Parsed parts: ['104', '110', '126', '138']
# Added bounding box: (104, 110, 126, 138)
# Line 4 in airplane_043.csv: 97 150 118 176
# Parsed parts: ['97', '150', '118', '176']
# Added bounding box: (97, 150, 118, 176)
# Processing airplane_313.csv, airplanes: 2
# Line 1 in airplane_313.csv: 38 4 171 98
# Parsed parts: ['38', '4', '171', '98']
# Added bounding box: (38, 4, 171, 98)
# Line 2 in airplane_313.csv: 145 183 215 247
# Parsed parts: ['145', '183', '215', '247']
# Added bounding box: (145, 183, 215, 247)
# Processing airplane_645.csv, airplanes: 3
# Line 1 in airplane_645.csv: 64 94 136 156
# Parsed parts: ['64', '94', '136', '156']
# Added bounding box: (64, 94, 136, 156)
# Line 2 in airplane_645.csv: 103 5 174 70
# Parsed parts: ['103', '5', '174', '70']
# Added bounding box: (103, 5, 174, 70)
# Line 3 in airplane_645.csv: 28 182 101 245
# Parsed parts: ['28', '182', '101', '245']
# Added bounding box: (28, 182, 101, 245)
# Processing airplane_002.csv, airplanes: 6
# Line 1 in airplane_002.csv: 123 18 151 49
# Parsed parts: ['123', '18', '151', '49']
# Added bounding box: (123, 18, 151, 49)
# Line 2 in airplane_002.csv: 162 25 187 48
# Parsed parts: ['162', '25', '187', '48']
# Added bounding box: (162, 25, 187, 48)
# Line 3 in airplane_002.csv: 20 83 35 112
# Parsed parts: ['20', '83', '35', '112']
# Added bounding box: (20, 83, 35, 112)
# Line 4 in airplane_002.csv: 44 87 73 115
# Parsed parts: ['44', '87', '73', '115']
# Added bounding box: (44, 87, 73, 115)
# Line 5 in airplane_002.csv: 83 86 110 116
# Parsed parts: ['83', '86', '110', '116']
# Added bounding box: (83, 86, 110, 116)
# Line 6 in airplane_002.csv: 112 90 141 123
# Parsed parts: ['112', '90', '141', '123']
# Added bounding box: (112, 90, 141, 123)
# Processing airplane_064.csv, airplanes: 1
# Line 1 in airplane_064.csv: 90 67 189 157
# Parsed parts: ['90', '67', '189', '157']
# Added bounding box: (90, 67, 189, 157)
# Processing airplane_601.csv, airplanes: 3
# Line 1 in airplane_601.csv: 106 87 143 127
# Parsed parts: ['106', '87', '143', '127']
# Added bounding box: (106, 87, 143, 127)
# Line 2 in airplane_601.csv: 33 29 64 61
# Parsed parts: ['33', '29', '64', '61']
# Added bounding box: (33, 29, 64, 61)
# Line 3 in airplane_601.csv: 175 140 207 181
# Parsed parts: ['175', '140', '207', '181']
# Added bounding box: (175, 140, 207, 181)
# Processing airplane_266.csv, airplanes: 2
# Line 1 in airplane_266.csv: 59 32 132 119
# Parsed parts: ['59', '32', '132', '119']
# Added bounding box: (59, 32, 132, 119)
# Line 2 in airplane_266.csv: 138 101 213 185
# Parsed parts: ['138', '101', '213', '185']
# Added bounding box: (138, 101, 213, 185)
# Processing airplane_443.csv, airplanes: 2
# Line 1 in airplane_443.csv: 82 31 133 73
# Parsed parts: ['82', '31', '133', '73']
# Added bounding box: (82, 31, 133, 73)
# Line 2 in airplane_443.csv: 169 88 228 136
# Parsed parts: ['169', '88', '228', '136']
# Added bounding box: (169, 88, 228, 136)
# Processing airplane_356.csv, airplanes: 1
# Line 1 in airplane_356.csv: 176 207 210 239
# Parsed parts: ['176', '207', '210', '239']
# Added bounding box: (176, 207, 210, 239)
# Processing airplane_470.csv, airplanes: 1
# Line 1 in airplane_470.csv: 73 74 184 159
# Parsed parts: ['73', '74', '184', '159']
# Added bounding box: (73, 74, 184, 159)
# Processing airplane_422.csv, airplanes: 4
# Line 1 in airplane_422.csv: 42 203 91 247
# Parsed parts: ['42', '203', '91', '247']
# Added bounding box: (42, 203, 91, 247)
# Line 2 in airplane_422.csv: 124 142 153 185
# Parsed parts: ['124', '142', '153', '185']
# Added bounding box: (124, 142, 153, 185)
# Line 3 in airplane_422.csv: 172 135 230 200
# Parsed parts: ['172', '135', '230', '200']
# Added bounding box: (172, 135, 230, 200)
# Line 4 in airplane_422.csv: 29 2 67 45
# Parsed parts: ['29', '2', '67', '45']
# Added bounding box: (29, 2, 67, 45)
# Processing airplane_112.csv, airplanes: 8
# Line 1 in airplane_112.csv: 17 31 83 95
# Parsed parts: ['17', '31', '83', '95']
# Added bounding box: (17, 31, 83, 95)
# Line 2 in airplane_112.csv: 103 16 153 61
# Parsed parts: ['103', '16', '153', '61']
# Added bounding box: (103, 16, 153, 61)
# Line 3 in airplane_112.csv: 104 66 153 110
# Parsed parts: ['104', '66', '153', '110']
# Added bounding box: (104, 66, 153, 110)
# Line 4 in airplane_112.csv: 110 120 160 163
# Parsed parts: ['110', '120', '160', '163']
# Added bounding box: (110, 120, 160, 163)
# Line 5 in airplane_112.csv: 18 117 86 178
# Parsed parts: ['18', '117', '86', '178']
# Added bounding box: (18, 117, 86, 178)
# Line 6 in airplane_112.csv: 113 169 162 214
# Parsed parts: ['113', '169', '162', '214']
# Added bounding box: (113, 169, 162, 214)
# Line 7 in airplane_112.csv: 27 215 47 238
# Parsed parts: ['27', '215', '47', '238']
# Added bounding box: (27, 215, 47, 238)
# Line 8 in airplane_112.csv: 33 237 58 257
# Parsed parts: ['33', '237', '58', '257']
# Added bounding box: (33, 237, 58, 257)
# Processing airplane_027.csv, airplanes: 2
# Line 1 in airplane_027.csv: 60 14 97 67
# Parsed parts: ['60', '14', '97', '67']
# Added bounding box: (60, 14, 97, 67)
# Line 2 in airplane_027.csv: 140 164 171 191
# Parsed parts: ['140', '164', '171', '191']
# Added bounding box: (140, 164, 171, 191)
# Processing airplane_322.csv, airplanes: 2
# Line 1 in airplane_322.csv: 86 117 127 154
# Parsed parts: ['86', '117', '127', '154']
# Added bounding box: (86, 117, 127, 154)
# Line 2 in airplane_322.csv: 153 84 180 119
# Parsed parts: ['153', '84', '180', '119']
# Added bounding box: (153, 84, 180, 119)
# Processing airplane_478.csv, airplanes: 10
# Line 1 in airplane_478.csv: 36 136 59 154
# Parsed parts: ['36', '136', '59', '154']
# Added bounding box: (36, 136, 59, 154)
# Line 2 in airplane_478.csv: 77 67 106 87
# Parsed parts: ['77', '67', '106', '87']
# Added bounding box: (77, 67, 106, 87)
# Line 3 in airplane_478.csv: 91 87 118 107
# Parsed parts: ['91', '87', '118', '107']
# Added bounding box: (91, 87, 118, 107)
# Line 4 in airplane_478.csv: 95 108 121 127
# Parsed parts: ['95', '108', '121', '127']
# Added bounding box: (95, 108, 121, 127)
# Line 5 in airplane_478.csv: 85 124 102 148
# Parsed parts: ['85', '124', '102', '148']
# Added bounding box: (85, 124, 102, 148)
# Line 6 in airplane_478.csv: 71 148 94 170
# Parsed parts: ['71', '148', '94', '170']
# Added bounding box: (71, 148, 94, 170)
# Line 7 in airplane_478.csv: 45 116 72 137
# Parsed parts: ['45', '116', '72', '137']
# Added bounding box: (45, 116, 72, 137)
# Line 8 in airplane_478.csv: 47 90 72 108
# Parsed parts: ['47', '90', '72', '108']
# Added bounding box: (47, 90, 72, 108)
# Line 9 in airplane_478.csv: 200 19 233 38
# Parsed parts: ['200', '19', '233', '38']
# Added bounding box: (200, 19, 233, 38)
# Line 10 in airplane_478.csv: 203 166 253 211
# Parsed parts: ['203', '166', '253', '211']
# Added bounding box: (203, 166, 253, 211)
# Processing airplane_227.csv, airplanes: 1
# Line 1 in airplane_227.csv: 99 56 243 163
# Parsed parts: ['99', '56', '243', '163']
# Added bounding box: (99, 56, 243, 163)
# Processing airplane_618.csv, airplanes: 3
# Line 1 in airplane_618.csv: 73 193 105 227
# Parsed parts: ['73', '193', '105', '227']
# Added bounding box: (73, 193, 105, 227)
# Line 2 in airplane_618.csv: 134 195 172 232
# Parsed parts: ['134', '195', '172', '232']
# Added bounding box: (134, 195, 172, 232)
# Line 3 in airplane_618.csv: 192 191 228 228
# Parsed parts: ['192', '191', '228', '228']
# Added bounding box: (192, 191, 228, 228)
# Processing airplane_477.csv, airplanes: 2
# Line 1 in airplane_477.csv: 12 79 111 202
# Parsed parts: ['12', '79', '111', '202']
# Added bounding box: (12, 79, 111, 202)
# Line 2 in airplane_477.csv: 164 60 232 146
# Parsed parts: ['164', '60', '232', '146']
# Added bounding box: (164, 60, 232, 146)
# Processing airplane_549.csv, airplanes: 1
# Line 1 in airplane_549.csv: 37 128 96 186
# Parsed parts: ['37', '128', '96', '186']
# Added bounding box: (37, 128, 96, 186)
# Processing airplane_664.csv, airplanes: 2
# Line 1 in airplane_664.csv: 122 6 149 27
# Parsed parts: ['122', '6', '149', '27']
# Added bounding box: (122, 6, 149, 27)
# Line 2 in airplane_664.csv: 181 3 209 37
# Parsed parts: ['181', '3', '209', '37']
# Added bounding box: (181, 3, 209, 37)
# Processing airplane_444.csv, airplanes: 2
# Line 1 in airplane_444.csv: 65 207 115 254
# Parsed parts: ['65', '207', '115', '254']
# Added bounding box: (65, 207, 115, 254)
# Line 2 in airplane_444.csv: 5 87 28 119
# Parsed parts: ['5', '87', '28', '119']
# Added bounding box: (5, 87, 28, 119)
# Processing airplane_094.csv, airplanes: 1
# Line 1 in airplane_094.csv: 157 160 190 197
# Parsed parts: ['157', '160', '190', '197']
# Added bounding box: (157, 160, 190, 197)
# Processing airplane_608.csv, airplanes: 2
# Line 1 in airplane_608.csv: 68 146 161 225
# Parsed parts: ['68', '146', '161', '225']
# Added bounding box: (68, 146, 161, 225)
# Line 2 in airplane_608.csv: 158 52 252 128
# Parsed parts: ['158', '52', '252', '128']
# Added bounding box: (158, 52, 252, 128)
# Processing airplane_682.csv, airplanes: 1
# Line 1 in airplane_682.csv: 63 14 146 114
# Parsed parts: ['63', '14', '146', '114']
# Added bounding box: (63, 14, 146, 114)
# Processing airplane_263.csv, airplanes: 6
# Line 1 in airplane_263.csv: 75 67 118 100
# Parsed parts: ['75', '67', '118', '100']
# Added bounding box: (75, 67, 118, 100)
# Line 2 in airplane_263.csv: 151 16 168 42
# Parsed parts: ['151', '16', '168', '42']
# Added bounding box: (151, 16, 168, 42)
# Line 3 in airplane_263.csv: 179 4 203 25
# Parsed parts: ['179', '4', '203', '25']
# Added bounding box: (179, 4, 203, 25)
# Line 4 in airplane_263.csv: 117 186 167 219
# Parsed parts: ['117', '186', '167', '219']
# Added bounding box: (117, 186, 167, 219)
# Line 5 in airplane_263.csv: 74 216 123 253
# Parsed parts: ['74', '216', '123', '253']
# Added bounding box: (74, 216, 123, 253)
# Line 6 in airplane_263.csv: 4 145 30 174
# Parsed parts: ['4', '145', '30', '174']
# Added bounding box: (4, 145, 30, 174)
# Processing airplane_298.csv, airplanes: 1
# Line 1 in airplane_298.csv: 11 196 73 247
# Parsed parts: ['11', '196', '73', '247']
# Added bounding box: (11, 196, 73, 247)
# Processing airplane_526.csv, airplanes: 4
# Line 1 in airplane_526.csv: 57 43 145 127
# Parsed parts: ['57', '43', '145', '127']
# Added bounding box: (57, 43, 145, 127)
# Line 2 in airplane_526.csv: 136 21 192 64
# Parsed parts: ['136', '21', '192', '64']
# Added bounding box: (136, 21, 192, 64)
# Line 3 in airplane_526.csv: 56 128 100 177
# Parsed parts: ['56', '128', '100', '177']
# Added bounding box: (56, 128, 100, 177)
# Line 4 in airplane_526.csv: 57 175 109 228
# Parsed parts: ['57', '175', '109', '228']
# Added bounding box: (57, 175, 109, 228)
# Processing airplane_016.csv, airplanes: 2
# Line 1 in airplane_016.csv: 128 22 166 57
# Parsed parts: ['128', '22', '166', '57']
# Added bounding box: (128, 22, 166, 57)
# Line 2 in airplane_016.csv: 199 103 237 137
# Parsed parts: ['199', '103', '237', '137']
# Added bounding box: (199, 103, 237, 137)
# Processing airplane_021.csv, airplanes: 2
# Line 1 in airplane_021.csv: 35 107 93 150
# Parsed parts: ['35', '107', '93', '150']
# Added bounding box: (35, 107, 93, 150)
# Line 2 in airplane_021.csv: 23 165 81 214
# Parsed parts: ['23', '165', '81', '214']
# Added bounding box: (23, 165, 81, 214)
# Processing airplane_109.csv, airplanes: 3
# Line 1 in airplane_109.csv: 82 45 135 95
# Parsed parts: ['82', '45', '135', '95']
# Added bounding box: (82, 45, 135, 95)
# Line 2 in airplane_109.csv: 36 41 64 64
# Parsed parts: ['36', '41', '64', '64']
# Added bounding box: (36, 41, 64, 64)
# Line 3 in airplane_109.csv: 158 80 191 114
# Parsed parts: ['158', '80', '191', '114']
# Added bounding box: (158, 80, 191, 114)
# Processing airplane_499.csv, airplanes: 2
# Line 1 in airplane_499.csv: 24 116 82 159
# Parsed parts: ['24', '116', '82', '159']
# Added bounding box: (24, 116, 82, 159)
# Line 2 in airplane_499.csv: 39 164 87 207
# Parsed parts: ['39', '164', '87', '207']
# Added bounding box: (39, 164, 87, 207)
# Processing airplane_360.csv, airplanes: 2
# Line 1 in airplane_360.csv: 72 139 104 182
# Parsed parts: ['72', '139', '104', '182']
# Added bounding box: (72, 139, 104, 182)
# Line 2 in airplane_360.csv: 153 111 189 156
# Parsed parts: ['153', '111', '189', '156']
# Added bounding box: (153, 111, 189, 156)
# Processing airplane_347.csv, airplanes: 13
# Line 1 in airplane_347.csv: 125 85 148 108
# Parsed parts: ['125', '85', '148', '108']
# Added bounding box: (125, 85, 148, 108)
# Line 2 in airplane_347.csv: 152 87 176 110
# Parsed parts: ['152', '87', '176', '110']
# Added bounding box: (152, 87, 176, 110)
# Line 3 in airplane_347.csv: 192 94 216 120
# Parsed parts: ['192', '94', '216', '120']
# Added bounding box: (192, 94, 216, 120)
# Line 4 in airplane_347.csv: 205 46 243 92
# Parsed parts: ['205', '46', '243', '92']
# Added bounding box: (205, 46, 243, 92)
# Line 5 in airplane_347.csv: 144 2 182 32
# Parsed parts: ['144', '2', '182', '32']
# Added bounding box: (144, 2, 182, 32)
# Line 6 in airplane_347.csv: 200 3 246 21
# Parsed parts: ['200', '3', '246', '21']
# Added bounding box: (200, 3, 246, 21)
# Line 7 in airplane_347.csv: 87 2 124 23
# Parsed parts: ['87', '2', '124', '23']
# Added bounding box: (87, 2, 124, 23)
# Line 8 in airplane_347.csv: 121 17 140 37
# Parsed parts: ['121', '17', '140', '37']
# Added bounding box: (121, 17, 140, 37)
# Line 9 in airplane_347.csv: 16 38 37 62
# Parsed parts: ['16', '38', '37', '62']
# Added bounding box: (16, 38, 37, 62)
# Line 10 in airplane_347.csv: 3 62 28 84
# Parsed parts: ['3', '62', '28', '84']
# Added bounding box: (3, 62, 28, 84)
# Line 11 in airplane_347.csv: 39 69 66 92
# Parsed parts: ['39', '69', '66', '92']
# Added bounding box: (39, 69, 66, 92)
# Line 12 in airplane_347.csv: 81 77 106 100
# Parsed parts: ['81', '77', '106', '100']
# Added bounding box: (81, 77, 106, 100)
# Line 13 in airplane_347.csv: 241 89 256 120
# Parsed parts: ['241', '89', '256', '120']
# Added bounding box: (241, 89, 256, 120)
# Processing airplane_613.csv, airplanes: 4
# Line 1 in airplane_613.csv: 59 201 120 249
# Parsed parts: ['59', '201', '120', '249']
# Added bounding box: (59, 201, 120, 249)
# Line 2 in airplane_613.csv: 134 212 187 250
# Parsed parts: ['134', '212', '187', '250']
# Added bounding box: (134, 212, 187, 250)
# Line 3 in airplane_613.csv: 142 190 181 212
# Parsed parts: ['142', '190', '181', '212']
# Added bounding box: (142, 190, 181, 212)
# Line 4 in airplane_613.csv: 102 196 138 215
# Parsed parts: ['102', '196', '138', '215']
# Added bounding box: (102, 196, 138, 215)
# Processing airplane_413.csv, airplanes: 2
# Line 1 in airplane_413.csv: 118 99 157 137
# Parsed parts: ['118', '99', '157', '137']
# Added bounding box: (118, 99, 157, 137)
# Line 2 in airplane_413.csv: 168 165 195 188
# Parsed parts: ['168', '165', '195', '188']
# Added bounding box: (168, 165, 195, 188)
# Processing airplane_646.csv, airplanes: 6
# Line 1 in airplane_646.csv: 6 104 42 142
# Parsed parts: ['6', '104', '42', '142']
# Added bounding box: (6, 104, 42, 142)
# Line 2 in airplane_646.csv: 23 163 66 204
# Parsed parts: ['23', '163', '66', '204']
# Added bounding box: (23, 163, 66, 204)
# Line 3 in airplane_646.csv: 68 33 89 66
# Parsed parts: ['68', '33', '89', '66']
# Added bounding box: (68, 33, 89, 66)
# Line 4 in airplane_646.csv: 107 49 129 78
# Parsed parts: ['107', '49', '129', '78']
# Added bounding box: (107, 49, 129, 78)
# Line 5 in airplane_646.csv: 133 67 153 89
# Parsed parts: ['133', '67', '153', '89']
# Added bounding box: (133, 67, 153, 89)
# Line 6 in airplane_646.csv: 189 119 218 146
# Parsed parts: ['189', '119', '218', '146']
# Added bounding box: (189, 119, 218, 146)
# Processing planes2.csv, airplanes: 69
# Line 1 in planes2.csv: 78 13 97 37
# Parsed parts: ['78', '13', '97', '37']
# Added bounding box: (78, 13, 97, 37)
# Line 2 in planes2.csv: 18 34 34 55
# Parsed parts: ['18', '34', '34', '55']
# Added bounding box: (18, 34, 34, 55)
# Line 3 in planes2.csv: 416 26 436 46
# Parsed parts: ['416', '26', '436', '46']
# Added bounding box: (416, 26, 436, 46)
# Line 4 in planes2.csv: 340 24 358 40
# Parsed parts: ['340', '24', '358', '40']
# Added bounding box: (340, 24, 358, 40)
# Line 5 in planes2.csv: 295 12 315 32
# Parsed parts: ['295', '12', '315', '32']
# Added bounding box: (295, 12, 315, 32)
# Line 6 in planes2.csv: 424 226 442 247
# Parsed parts: ['424', '226', '442', '247']
# Added bounding box: (424, 226, 442, 247)
# Line 7 in planes2.csv: 345 265 364 287
# ...
# Added bounding box: (310, 227, 368, 286)
# Line 8 in Planes9.csv: 129 93 179 156
# Parsed parts: ['129', '93', '179', '156']
# Added bounding box: (129, 93, 179, 156)
# Line 9 in Planes9.csv: 32 44 92 109
# Parsed parts: ['32', '44', '92', '109']
# Added bounding box: (32, 44, 92, 109)
# Line 10 in Planes9.csv: 63 95 124 151
# Parsed parts: ['63', '95', '124', '151']
# Added bounding box: (63, 95, 124, 151)
# Line 11 in Planes9.csv: 96 40 149 104
# Parsed parts: ['96', '40', '149', '104']
# Added bounding box: (96, 40, 149, 104)
# Line 12 in Planes9.csv: 154 39 210 107
# Parsed parts: ['154', '39', '210', '107']
# Added bounding box: (154, 39, 210, 107)
# Line 13 in Planes9.csv: 185 93 246 156
# Parsed parts: ['185', '93', '246', '156']
# Added bounding box: (185, 93, 246, 156)
# Line 14 in Planes9.csv: 277 38 333 105
# Parsed parts: ['277', '38', '333', '105']
# Added bounding box: (277, 38, 333, 105)
# Line 15 in Planes9.csv: 249 90 313 156
# Parsed parts: ['249', '90', '313', '156']
# Added bounding box: (249, 90, 313, 156)
# Line 16 in Planes9.csv: 335 37 393 100
# Parsed parts: ['335', '37', '393', '100']
# Added bounding box: (335, 37, 393, 100)
# Line 17 in Planes9.csv: 369 84 428 147
# Parsed parts: ['369', '84', '428', '147']
# Added bounding box: (369, 84, 428, 147)
# Line 18 in Planes9.csv: 251 226 304 287
# Parsed parts: ['251', '226', '304', '287']
# Added bounding box: (251, 226, 304, 287)
# Line 19 in Planes9.csv: 280 273 337 344
# Parsed parts: ['280', '273', '337', '344']
# Added bounding box: (280, 273, 337, 344)
# Line 20 in Planes9.csv: 339 269 402 344
# Parsed parts: ['339', '269', '402', '344']
# Added bounding box: (339, 269, 402, 344)
# Line 21 in Planes9.csv: 370 221 428 286
# Parsed parts: ['370', '221', '428', '286']
# Added bounding box: (370, 221, 428, 286)
# Processing airplane_599.csv, airplanes: 3
# Line 1 in airplane_599.csv: 132 110 167 142
# Parsed parts: ['132', '110', '167', '142']
# Added bounding box: (132, 110, 167, 142)
# Line 2 in airplane_599.csv: 77 170 109 195
# Parsed parts: ['77', '170', '109', '195']
# Added bounding box: (77, 170, 109, 195)
# Line 3 in airplane_599.csv: 105 199 132 227
# Parsed parts: ['105', '199', '132', '227']
# Added bounding box: (105, 199, 132, 227)
# Processing airplane_644.csv, airplanes: 2
# Line 1 in airplane_644.csv: 84 36 162 98
# Parsed parts: ['84', '36', '162', '98']
# Added bounding box: (84, 36, 162, 98)
# Line 2 in airplane_644.csv: 90 115 133 170
# Parsed parts: ['90', '115', '133', '170']
# Added bounding box: (90, 115, 133, 170)
# Processing airplane_641.csv, airplanes: 4
# Line 1 in airplane_641.csv: 171 139 196 171
# Parsed parts: ['171', '139', '196', '171']
# Added bounding box: (171, 139, 196, 171)
# Line 2 in airplane_641.csv: 206 116 237 146
# Parsed parts: ['206', '116', '237', '146']
# Added bounding box: (206, 116, 237, 146)
# Line 3 in airplane_641.csv: 76 61 108 91
# Parsed parts: ['76', '61', '108', '91']
# Added bounding box: (76, 61, 108, 91)
# Line 4 in airplane_641.csv: 245 19 255 31
# Parsed parts: ['245', '19', '255', '31']
# Added bounding box: (245, 19, 255, 31)
# Processing 428481.csv, airplanes: 2
# Line 1 in 428481.csv: 155 14 188 45
# Parsed parts: ['155', '14', '188', '45']
# Added bounding box: (155, 14, 188, 45)
# Line 2 in 428481.csv: 219 57 253 86
# Parsed parts: ['219', '57', '253', '86']
# Added bounding box: (219, 57, 253, 86)
# Processing airplane_045.csv, airplanes: 5
# Line 1 in airplane_045.csv: 51 17 137 84
# Parsed parts: ['51', '17', '137', '84']
# Added bounding box: (51, 17, 137, 84)
# Line 2 in airplane_045.csv: 137 66 206 124
# Parsed parts: ['137', '66', '206', '124']
# Added bounding box: (137, 66, 206, 124)
# Line 3 in airplane_045.csv: 106 137 147 166
# Parsed parts: ['106', '137', '147', '166']
# Added bounding box: (106, 137, 147, 166)
# Line 4 in airplane_045.csv: 81 174 116 205
# Parsed parts: ['81', '174', '116', '205']
# Added bounding box: (81, 174, 116, 205)
# Line 5 in airplane_045.csv: 39 204 83 248
# Parsed parts: ['39', '204', '83', '248']
# Added bounding box: (39, 204, 83, 248)
# Processing airplane_010.csv, airplanes: 2
# Line 1 in airplane_010.csv: 18 183 57 220
# Parsed parts: ['18', '183', '57', '220']
# Added bounding box: (18, 183, 57, 220)
# Line 2 in airplane_010.csv: 70 218 125 254
# Parsed parts: ['70', '218', '125', '254']
# Added bounding box: (70, 218, 125, 254)
# Processing airplane_580.csv, airplanes: 21
# Line 1 in airplane_580.csv: 154 153 172 172
# Parsed parts: ['154', '153', '172', '172']
# Added bounding box: (154, 153, 172, 172)
# Line 2 in airplane_580.csv: 161 131 172 146
# Parsed parts: ['161', '131', '172', '146']
# Added bounding box: (161, 131, 172, 146)
# Line 3 in airplane_580.csv: 169 109 184 128
# Parsed parts: ['169', '109', '184', '128']
# Added bounding box: (169, 109, 184, 128)
# Line 4 in airplane_580.csv: 170 84 191 103
# Parsed parts: ['170', '84', '191', '103']
# Added bounding box: (170, 84, 191, 103)
# Line 5 in airplane_580.csv: 190 44 207 63
# Parsed parts: ['190', '44', '207', '63']
# Added bounding box: (190, 44, 207, 63)
# Line 6 in airplane_580.csv: 199 30 218 40
# Parsed parts: ['199', '30', '218', '40']
# Added bounding box: (199, 30, 218, 40)
# Line 7 in airplane_580.csv: 129 44 150 64
# Parsed parts: ['129', '44', '150', '64']
# Added bounding box: (129, 44, 150, 64)
# Line 8 in airplane_580.csv: 99 112 116 131
# Parsed parts: ['99', '112', '116', '131']
# Added bounding box: (99, 112, 116, 131)
# Line 9 in airplane_580.csv: 92 135 108 151
# Parsed parts: ['92', '135', '108', '151']
# Added bounding box: (92, 135, 108, 151)
# Line 10 in airplane_580.csv: 70 125 85 140
# Parsed parts: ['70', '125', '85', '140']
# Added bounding box: (70, 125, 85, 140)
# Line 11 in airplane_580.csv: 68 137 75 148
# Parsed parts: ['68', '137', '75', '148']
# Added bounding box: (68, 137, 75, 148)
# Line 12 in airplane_580.csv: 58 148 69 161
# Parsed parts: ['58', '148', '69', '161']
# Added bounding box: (58, 148, 69, 161)
# Line 13 in airplane_580.csv: 53 161 65 180
# Parsed parts: ['53', '161', '65', '180']
# Added bounding box: (53, 161, 65, 180)
# Line 14 in airplane_580.csv: 34 192 54 206
# Parsed parts: ['34', '192', '54', '206']
# Added bounding box: (34, 192, 54, 206)
# Line 15 in airplane_580.csv: 59 197 83 216
# Parsed parts: ['59', '197', '83', '216']
# Added bounding box: (59, 197, 83, 216)
# Line 16 in airplane_580.csv: 72 176 88 191
# Parsed parts: ['72', '176', '88', '191']
# Added bounding box: (72, 176, 88, 191)
# Line 17 in airplane_580.csv: 76 157 103 172
# Parsed parts: ['76', '157', '103', '172']
# Added bounding box: (76, 157, 103, 172)
# Line 18 in airplane_580.csv: 134 195 152 214
# Parsed parts: ['134', '195', '152', '214']
# Added bounding box: (134, 195, 152, 214)
# Line 19 in airplane_580.csv: 129 217 149 237
# Parsed parts: ['129', '217', '149', '237']
# Added bounding box: (129, 217, 149, 237)
# Line 20 in airplane_580.csv: 124 1 136 13
# Parsed parts: ['124', '1', '136', '13']
# Added bounding box: (124, 1, 136, 13)
# Line 21 in airplane_580.csv: 116 16 132 36
# Parsed parts: ['116', '16', '132', '36']
# Added bounding box: (116, 16, 132, 36)
# Processing airplane_411.csv, airplanes: 1
# Line 1 in airplane_411.csv: 72 122 131 183
# Parsed parts: ['72', '122', '131', '183']
# Added bounding box: (72, 122, 131, 183)
# Processing airplane_167.csv, airplanes: 2
# Line 1 in airplane_167.csv: 124 47 206 115
# Parsed parts: ['124', '47', '206', '115']
# Added bounding box: (124, 47, 206, 115)
# Line 2 in airplane_167.csv: 143 127 223 200
# Parsed parts: ['143', '127', '223', '200']
# Added bounding box: (143, 127, 223, 200)
# Processing airplane_337.csv, airplanes: 4
# Line 1 in airplane_337.csv: 4 26 41 63
# Parsed parts: ['4', '26', '41', '63']
# Added bounding box: (4, 26, 41, 63)
# Line 2 in airplane_337.csv: 13 65 60 97
# Parsed parts: ['13', '65', '60', '97']
# Added bounding box: (13, 65, 60, 97)
# Line 3 in airplane_337.csv: 24 108 62 141
# Parsed parts: ['24', '108', '62', '141']
# Added bounding box: (24, 108, 62, 141)
# Line 4 in airplane_337.csv: 29 207 65 239
# Parsed parts: ['29', '207', '65', '239']
# Added bounding box: (29, 207, 65, 239)
# Processing airplane_589.csv, airplanes: 2
# Line 1 in airplane_589.csv: 26 61 111 115
# Parsed parts: ['26', '61', '111', '115']
# Added bounding box: (26, 61, 111, 115)
# Line 2 in airplane_589.csv: 126 106 213 166
# Parsed parts: ['126', '106', '213', '166']
# Added bounding box: (126, 106, 213, 166)
# Processing airplane_595.csv, airplanes: 2
# Line 1 in airplane_595.csv: 54 67 92 104
# Parsed parts: ['54', '67', '92', '104']
# Added bounding box: (54, 67, 92, 104)
# Line 2 in airplane_595.csv: 102 46 143 79
# Parsed parts: ['102', '46', '143', '79']
# Added bounding box: (102, 46, 143, 79)
# Processing airplane_535.csv, airplanes: 1
# Line 1 in airplane_535.csv: 167 138 221 191
# Parsed parts: ['167', '138', '221', '191']
# Added bounding box: (167, 138, 221, 191)
# Processing airplane_401.csv, airplanes: 2
# Line 1 in airplane_401.csv: 5 90 52 132
# Parsed parts: ['5', '90', '52', '132']
# Added bounding box: (5, 90, 52, 132)
# Line 2 in airplane_401.csv: 199 115 245 159
# Parsed parts: ['199', '115', '245', '159']
# Added bounding box: (199, 115, 245, 159)
# Processing airplane_344.csv, airplanes: 3
# Line 1 in airplane_344.csv: 133 14 167 49
# Parsed parts: ['133', '14', '167', '49']
# Added bounding box: (133, 14, 167, 49)
# Line 2 in airplane_344.csv: 164 53 200 89
# Parsed parts: ['164', '53', '200', '89']
# Added bounding box: (164, 53, 200, 89)
# Line 3 in airplane_344.csv: 198 92 234 133
# Parsed parts: ['198', '92', '234', '133']
# Added bounding box: (198, 92, 234, 133)
# Processing airplane_690.csv, airplanes: 3
# Line 1 in airplane_690.csv: 95 101 179 166
# Parsed parts: ['95', '101', '179', '166']
# Added bounding box: (95, 101, 179, 166)
# Line 2 in airplane_690.csv: 140 33 223 96
# Parsed parts: ['140', '33', '223', '96']
# Added bounding box: (140, 33, 223, 96)
# Line 3 in airplane_690.csv: 52 168 129 236
# Parsed parts: ['52', '168', '129', '236']
# Added bounding box: (52, 168, 129, 236)
# Processing airplane_106.csv, airplanes: 8
# Line 1 in airplane_106.csv: 29 18 65 55
# Parsed parts: ['29', '18', '65', '55']
# Added bounding box: (29, 18, 65, 55)
# Line 2 in airplane_106.csv: 71 29 93 55
# Parsed parts: ['71', '29', '93', '55']
# Added bounding box: (71, 29, 93, 55)
# Line 3 in airplane_106.csv: 95 33 116 60
# Parsed parts: ['95', '33', '116', '60']
# Added bounding box: (95, 33, 116, 60)
# Line 4 in airplane_106.csv: 117 33 146 60
# Parsed parts: ['117', '33', '146', '60']
# Added bounding box: (117, 33, 146, 60)
# Line 5 in airplane_106.csv: 146 34 171 61
# Parsed parts: ['146', '34', '171', '61']
# Added bounding box: (146, 34, 171, 61)
# Line 6 in airplane_106.csv: 173 28 201 57
# Parsed parts: ['173', '28', '201', '57']
# Added bounding box: (173, 28, 201, 57)
# Line 7 in airplane_106.csv: 197 28 222 55
# Parsed parts: ['197', '28', '222', '55']
# Added bounding box: (197, 28, 222, 55)
# Line 8 in airplane_106.csv: 219 16 243 45
# Parsed parts: ['219', '16', '243', '45']
# Added bounding box: (219, 16, 243, 45)
# Processing airplane_161.csv, airplanes: 2
# Line 1 in airplane_161.csv: 105 41 203 121
# Parsed parts: ['105', '41', '203', '121']
# Added bounding box: (105, 41, 203, 121)
# Line 2 in airplane_161.csv: 90 165 133 208
# Parsed parts: ['90', '165', '133', '208']
# Added bounding box: (90, 165, 133, 208)
# Processing airplane_684.csv, airplanes: 1
# Line 1 in airplane_684.csv: 84 78 141 119
# Parsed parts: ['84', '78', '141', '119']
# Added bounding box: (84, 78, 141, 119)
# Processing airplane_594.csv, airplanes: 1
# Line 1 in airplane_594.csv: 91 83 177 192
# Parsed parts: ['91', '83', '177', '192']
# Added bounding box: (91, 83, 177, 192)
# Processing airplane_295.csv, airplanes: 4
# Line 1 in airplane_295.csv: 10 208 49 244
# Parsed parts: ['10', '208', '49', '244']
# Added bounding box: (10, 208, 49, 244)
# Line 2 in airplane_295.csv: 42 164 81 199
# Parsed parts: ['42', '164', '81', '199']
# Added bounding box: (42, 164, 81, 199)
# Line 3 in airplane_295.csv: 82 128 116 169
# Parsed parts: ['82', '128', '116', '169']
# Added bounding box: (82, 128, 116, 169)
# Line 4 in airplane_295.csv: 163 72 193 110
# Parsed parts: ['163', '72', '193', '110']
# Added bounding box: (163, 72, 193, 110)
# Processing airplane_251.csv, airplanes: 1
# Line 1 in airplane_251.csv: 78 87 180 188
# Parsed parts: ['78', '87', '180', '188']
# Added bounding box: (78, 87, 180, 188)
# Processing airplane_502.csv, airplanes: 5
# Line 1 in airplane_502.csv: 114 122 147 153
# Parsed parts: ['114', '122', '147', '153']
# Added bounding box: (114, 122, 147, 153)
# Line 2 in airplane_502.csv: 134 160 173 202
# Parsed parts: ['134', '160', '173', '202']
# Added bounding box: (134, 160, 173, 202)
# Line 3 in airplane_502.csv: 177 188 207 227
# Parsed parts: ['177', '188', '207', '227']
# Added bounding box: (177, 188, 207, 227)
# Line 4 in airplane_502.csv: 84 152 117 179
# Parsed parts: ['84', '152', '117', '179']
# Added bounding box: (84, 152, 117, 179)
# Line 5 in airplane_502.csv: 242 2 254 20
# Parsed parts: ['242', '2', '254', '20']
# Added bounding box: (242, 2, 254, 20)
# Processing airplane_115.csv, airplanes: 2
# Line 1 in airplane_115.csv: 151 50 212 116
# Parsed parts: ['151', '50', '212', '116']
# Added bounding box: (151, 50, 212, 116)
# Line 2 in airplane_115.csv: 47 109 115 186
# Parsed parts: ['47', '109', '115', '186']
# Added bounding box: (47, 109, 115, 186)
# Processing airplane_387.csv, airplanes: 4
# Line 1 in airplane_387.csv: 29 12 73 47
# Parsed parts: ['29', '12', '73', '47']
# Added bounding box: (29, 12, 73, 47)
# Line 2 in airplane_387.csv: 87 153 121 191
# Parsed parts: ['87', '153', '121', '191']
# Added bounding box: (87, 153, 121, 191)
# Line 3 in airplane_387.csv: 169 132 215 168
# Parsed parts: ['169', '132', '215', '168']
# Added bounding box: (169, 132, 215, 168)
# Line 4 in airplane_387.csv: 2 85 37 118
# Parsed parts: ['2', '85', '37', '118']
# Added bounding box: (2, 85, 37, 118)
# Processing airplane_238.csv, airplanes: 1
# Line 1 in airplane_238.csv: 94 57 180 126
# Parsed parts: ['94', '57', '180', '126']
# Added bounding box: (94, 57, 180, 126)
# Processing airplane_634.csv, airplanes: 2
# Line 1 in airplane_634.csv: 60 16 131 86
# Parsed parts: ['60', '16', '131', '86']
# Added bounding box: (60, 16, 131, 86)
# Line 2 in airplane_634.csv: 195 154 234 200
# Parsed parts: ['195', '154', '234', '200']
# Added bounding box: (195, 154, 234, 200)
# Processing airplane_655.csv, airplanes: 5
# Line 1 in airplane_655.csv: 78 83 119 121
# Parsed parts: ['78', '83', '119', '121']
# Added bounding box: (78, 83, 119, 121)
# Line 2 in airplane_655.csv: 99 141 124 165
# Parsed parts: ['99', '141', '124', '165']
# Added bounding box: (99, 141, 124, 165)
# Line 3 in airplane_655.csv: 112 198 142 222
# Parsed parts: ['112', '198', '142', '222']
# Added bounding box: (112, 198, 142, 222)
# Line 4 in airplane_655.csv: 115 228 146 252
# Parsed parts: ['115', '228', '146', '252']
# Added bounding box: (115, 228, 146, 252)
# Line 5 in airplane_655.csv: 28 104 51 132
# Parsed parts: ['28', '104', '51', '132']
# Added bounding box: (28, 104, 51, 132)
# Processing airplane_308.csv, airplanes: 3
# Line 1 in airplane_308.csv: 114 72 173 142
# Parsed parts: ['114', '72', '173', '142']
# Added bounding box: (114, 72, 173, 142)
# Line 2 in airplane_308.csv: 166 27 228 99
# Parsed parts: ['166', '27', '228', '99']
# Added bounding box: (166, 27, 228, 99)
# Line 3 in airplane_308.csv: 5 151 67 226
# Parsed parts: ['5', '151', '67', '226']
# Added bounding box: (5, 151, 67, 226)
# Processing airplane_379.csv, airplanes: 2
# Line 1 in airplane_379.csv: 31 155 90 214
# Parsed parts: ['31', '155', '90', '214']
# Added bounding box: (31, 155, 90, 214)
# Line 2 in airplane_379.csv: 213 112 252 149
# Parsed parts: ['213', '112', '252', '149']
# Added bounding box: (213, 112, 252, 149)
# Processing airplane_679.csv, airplanes: 1
# Line 1 in airplane_679.csv: 5 170 36 198
# Parsed parts: ['5', '170', '36', '198']
# Added bounding box: (5, 170, 36, 198)
# Processing airplane_310.csv, airplanes: 3
# Line 1 in airplane_310.csv: 93 4 129 35
# Parsed parts: ['93', '4', '129', '35']
# Added bounding box: (93, 4, 129, 35)
# Line 2 in airplane_310.csv: 40 45 56 61
# Parsed parts: ['40', '45', '56', '61']
# Added bounding box: (40, 45, 56, 61)
# Line 3 in airplane_310.csv: 2 65 20 91
# Parsed parts: ['2', '65', '20', '91']
# Added bounding box: (2, 65, 20, 91)
# Total valid annotations: 2906
# Data split completed. Processed dataset saved in 'Processed_Dataset'

# %%
# !pip install torch torchvision matplotlib scikit-learn
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
# !pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.1.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (11.0.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.26.4)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.19-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (655 bytes)
# Downloading visualkeras-0.1.4-py3-none-any.whl (17 kB)
# Downloading aggdraw-1.3.19-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.7/993.7 kB 18.3 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.19 visualkeras-0.1.4

# %%
import os
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
import torch.optim as optim
from PIL import Image
import cv2
import numpy as np
from skimage import color
from skimage.segmentation import slic
import torch.nn.functional as F

class AirplaneDataset(Dataset):
    def __init__(self, image_dir="airplanes_data/Images/Images", annotation_dir="airplanes_data/Airplanes_Annotations/Airplanes_Annotations", transform=None):
        self.image_dir = image_dir
        self.annotation_dir = annotation_dir
        self.transform = transform
        self.images = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_name = self.images[idx]
        image_path = os.path.join(self.image_dir, image_name)
        image = Image.open(image_path).convert("RGB")
        annotation_path = os.path.join(self.annotation_dir, image_name.replace(".jpg", ".txt"))
        boxes = []
        labels = []

        with open(annotation_path, 'r') as f:
            lines = f.readlines()
            for line in lines:
                parts = line.strip().split()
                label = parts[0]
                x_min, y_min, x_max, y_max = map(int, parts[1:])
                boxes.append([x_min, y_min, x_max, y_max])
                labels.append(0)

        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = torch.tensor([idx])

        if self.transform:
            image = self.transform(image)

        return image, target

train_image_dir = 'Processed_Dataset5/train'
train_annotation_dir = 'Processed_Dataset5/train'

transform = transforms.Compose([transforms.ToTensor()])
train_dataset = AirplaneDataset(image_dir=train_image_dir, annotation_dir=train_annotation_dir, transform=transform)

train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size

train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])
train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))
val_loader = DataLoader(val_dataset, batch_size=2, shuffle=False, collate_fn=lambda x: tuple(zip(*x)))

def selective_search(image):
    image = image.cpu().numpy().transpose((1, 2, 0))
    image = (image * 255).astype(np.uint8)
    gray_image = color.rgb2gray(image)
    segments = slic(image, n_segments=100, compactness=10, sigma=1)
    regions = []
    for label in np.unique(segments):
        segment_mask = (segments == label)
        coords = np.argwhere(segment_mask)
        y_min, x_min = coords.min(axis=0)
        y_max, x_max = coords.max(axis=0)
        regions.append([x_min, y_min, x_max, y_max])
    return regions

class RegionBasedRCNN(torch.nn.Module):
    def __init__(self, backbone, num_classes, resize_dim=(224, 224)):
        super().__init__()
        self.backbone = backbone
        self.classifier = torch.nn.Linear(2048, num_classes)
        self.resize_dim = resize_dim

    def forward(self, images, regions):
        region_features = []
        for image, region_list in zip(images, regions):
            for region in region_list:
                if len(region) == 4:
                    x_min, y_min, x_max, y_max = region
                    region_image = image[:, y_min:y_max, x_min:x_max]
                    region_image_resized = F.interpolate(region_image.unsqueeze(0), size=self.resize_dim)
                    region_features.append(region_image_resized.squeeze(0))
        
        if len(region_features) == 0:
            return torch.tensor([])

        region_features = torch.stack(region_features)
        features = self.backbone(region_features)
        flattened_features = features.flatten(1)
        output = self.classifier(flattened_features)
        return output

backbone = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)
backbone = torch.nn.Sequential(*list(backbone.children())[:-1])

model = RegionBasedRCNN(backbone, num_classes=2)

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model.to(device)

optimizer = optim.Adam(model.parameters(), lr=1e-4)

def compute_loss(output, targets):
    all_predictions = []
    all_target_labels = []

    for image_idx, (output_image, target) in enumerate(zip(output, targets)):
        num_regions = len(target['boxes'])
        target_labels = target['labels']
        
        target_labels = target_labels.long()

        if num_regions != output_image.size(0):
            output_image = output_image[:num_regions, :]
            target_labels = target_labels[:num_regions]

        all_predictions.append(output_image)
        all_target_labels.append(target_labels)

    all_predictions = torch.cat(all_predictions, dim=0)
    all_target_labels = torch.cat(all_target_labels, dim=0)

    loss = torch.nn.CrossEntropyLoss()(all_predictions, all_target_labels)
    return loss

num_epochs = 7
for epoch in range(num_epochs):
    model.train()
    for images, targets in train_loader:
        images = [image.to(device) for image in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        region_proposals = [selective_search(image) for image in images]

        optimizer.zero_grad()

        output = model(images, region_proposals)

        loss = compute_loss(output, targets)

        loss.backward()
        optimizer.step()

    print(f"Epoch {epoch + 1}, Loss: {loss.item()}")

def compute_iou(true_boxes, pred_boxes):
    ious = []
    if len(pred_boxes) == 0:
        return [0] * len(true_boxes)

    for true_box in true_boxes:
        ious_per_true_box = []
        for pred_box in pred_boxes:
            x_min1, y_min1, x_max1, y_max1 = true_box
            x_min2, y_min2, x_max2, y_max2 = pred_box

            x_min = max(x_min1, x_min2)
            y_min = max(y_min1, y_min2)
            x_max = min(x_max1, x_max2)
            y_max = min(y_max1, y_max2)

            intersection_area = max(0, x_max - x_min) * max(0, y_max - y_min)
            area_true = (x_max1 - x_min1) * (y_max1 - y_min1)
            area_pred = (x_max2 - x_min2) * (y_max2 - y_min2)
            union_area = area_true + area_pred - intersection_area

            iou = intersection_area / union_area if union_area != 0 else 0
            ious_per_true_box.append(iou)

        if ious_per_true_box:
            ious.append(max(ious_per_true_box))
        else:
            ious.append(0)

    return ious
# Out:
# Epoch 1, Loss: 0.006399523466825485
# Epoch 2, Loss: 0.01088955719023943
# Epoch 3, Loss: 0.031332265585660934
# Epoch 4, Loss: 0.0013006175868213177
# Epoch 5, Loss: 0.005467038601636887
# Epoch 6, Loss: 0.0059882295317947865
# Epoch 7, Loss: 0.004345413763076067
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.

# %%
import torch
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from collections import defaultdict
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from torchvision.transforms import functional as F

def compute_iou(true_boxes, pred_boxes):
   
    ious = []
    for true_box in true_boxes:
        for pred_box in pred_boxes:
            x1 = max(true_box[0], pred_box[0])
            y1 = max(true_box[1], pred_box[1])
            x2 = min(true_box[2], pred_box[2])
            y2 = min(true_box[3], pred_box[3])

    
            intersection_area = max(0, x2 - x1) * max(0, y2 - y1)

           
            true_area = (true_box[2] - true_box[0]) * (true_box[3] - true_box[1])
            pred_area = (pred_box[2] - pred_box[0]) * (pred_box[3] - pred_box[1])

            
            union_area = true_area + pred_area - intersection_area
            iou = intersection_area / union_area if union_area > 0 else 0
            ious.append(iou)

    return np.array(ious)

def calculate_ap_at_iou_threshold(true_boxes, pred_boxes, pred_scores, iou_threshold=0.5):
  
    ious = compute_iou(true_boxes, pred_boxes)
    true_positive = ious >= iou_threshold


    if true_positive.size == 0 or np.sum(true_positive) == 0:
        return 0.0

 
    sorted_idx = np.argsort(pred_scores)[::-1]  
    sorted_true_positive = true_positive[sorted_idx]
    sorted_scores = pred_scores[sorted_idx]

    
    tp = np.cumsum(sorted_true_positive)  
    fp = np.cumsum(1 - sorted_true_positive)  

    precision = tp / (tp + fp + np.finfo(float).eps)  
    recall = tp / len(true_boxes)


    ap = np.mean(precision)
    return ap

def evaluate_model_on_test(model, data_loader, iou_thresholds=[0.5, 0.75]):
    model.eval()

  
    all_preds = defaultdict(list)
    all_labels = defaultdict(list)

    with torch.no_grad():
        for images, targets in data_loader:
            images = [image.to(device) for image in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

            predictions = model(images)

            for target, prediction in zip(targets, predictions):
                true_boxes = target["boxes"].cpu().numpy()
                pred_boxes = prediction['boxes'].cpu().numpy()
                pred_scores = prediction['scores'].cpu().numpy()

                true_labels = target["labels"].cpu().numpy()
                pred_labels = prediction['labels'].cpu().numpy()

                for iou_threshold in iou_thresholds:
                
                    ap = calculate_ap_at_iou_threshold(true_boxes, pred_boxes, pred_scores, iou_threshold)
                    all_preds[iou_threshold].append(ap)
                    all_labels[iou_threshold].append([1] * len(true_boxes))  

    # Calculate AP for each IoU threshold
    ap_results = {}
    for iou_threshold in iou_thresholds:
        ap_results[f'AP@{iou_threshold}'] = np.mean(all_preds[iou_threshold]) 

    return ap_results



test_image_dir = 'Processed_Dataset/test'
test_annotation_dir = 'Processed_Dataset/test'

test_dataset = AirplaneDataset(image_dir=test_image_dir, annotation_dir=test_annotation_dir, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=2, shuffle=False, collate_fn=lambda x: tuple(zip(*x)))

ap_results = evaluate_model_on_test(model, test_loader, iou_thresholds=[0.5, 0.75])
for iou_threshold, ap in ap_results.items():
    print(f"{iou_threshold}: {ap:.4f}")
# Out:
# AP@0.5: 0.7281
# AP@0.75: 0.5905

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import torch
from PIL import Image
from torchvision.transforms import functional as F

def visualize_predictions(model, image, target, prediction, threshold=0.5):

    image = F.to_pil_image(image.cpu())


    fig, ax = plt.subplots(1, figsize=(12, 9))
    ax.imshow(image)

 
    true_boxes = target['boxes'].cpu().numpy()
    true_labels = target['labels'].cpu().numpy()


 
    pred_boxes = prediction['boxes'].cpu().numpy()
    pred_scores = prediction['scores'].cpu().numpy()

    for box, score in zip(pred_boxes, pred_scores):
        if score > threshold:
            rect = patches.Rectangle(
                (box[0], box[1]), box[2] - box[0], box[3] - box[1],
                linewidth=2, edgecolor='r', facecolor='none')
            ax.add_patch(rect)
            ax.text(box[0], box[1] - 5, f'{score:.2f}', color='r', fontsize=12)

 
    plt.axis('off')
    plt.show()


def visualize_random_sample_prediction(model, data_loader):
    model.eval()  
  
    random_batch_idx = random.randint(0, len(data_loader) - 1)
    images, targets = list(data_loader)[random_batch_idx]
    images = [image.to(device) for image in images]
    targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

 
    with torch.no_grad():
        predictions = model(images)

    
    visualize_predictions(model, images[0], targets[0], predictions[0])


visualize_random_sample_prediction(model, test_loader)
